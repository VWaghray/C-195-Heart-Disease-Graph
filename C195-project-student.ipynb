# %%
print("Name: Vihaan")
print("We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level")
print("We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it")
# Out:
# Name: Vihaan
# We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level
# We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it

# %% [markdown]
# # Task 1 - Find the diabetic and hight blood pressure patients across all age groups, and conclude the risk heart stroke is higher in which age group

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt 

#read the csv
df = pd.read_csv('heart_disease.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 0                      1  265000.00               1.9           130       1
# 1                      0  263358.03               1.1           136       1
# 2                      0  162000.00               1.3           129       1
# 3                      0  210000.00               1.9           137       1
# 4                      0  327000.00               2.7           116       0
# ..                   ...        ...               ...           ...     ...
# 294                    1  155000.00               1.1           143       1
# 295                    0  270000.00               1.2           139       0
# 296                    0  742000.00               0.8           138       0
# 297                    0  140000.00               1.4           140       1
# 298                    0  395000.00               1.6           136       1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
#Filter by diabetes(condition will be who has diabetes) and create new dataframe
dp = df.loc[df["diabetes"] == 1]
dp
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4    65.0        1                       160         1                 20
# 7    60.0        1                       315         1                 60
# 19   48.0        1                       582         1                 55
# 21   65.0        1                       128         1                 30
# 23   53.0        0                        63         1                 60
# ..    ...      ...                       ...       ...                ...
# 290  45.0        0                       615         1                 55
# 292  52.0        0                       190         1                 38
# 293  63.0        1                       103         1                 35
# 294  62.0        0                        61         1                 38
# 296  45.0        0                      2060         1                 60
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 4                      0   327000.0               2.7           116       0
# 7                      0   454000.0               1.1           131       1
# 19                     0    87000.0               1.9           121       0
# 21                     1   297000.0               1.6           136       0
# 23                     0   368000.0               0.8           135       1
# ..                   ...        ...               ...           ...     ...
# 290                    0   222000.0               0.8           141       0
# 292                    0   382000.0               1.0           140       1
# 293                    0   179000.0               0.9           136       1
# 294                    1   155000.0               1.1           143       1
# 296                    0   742000.0               0.8           138       0
#
#      smoking  time  DEATH_EVENT
# 4          0     8            1
# 7          1    10            1
# 19         0    15            1
# 21         0    20            1
# 23         0    22            0
# ..       ...   ...          ...
# 290        0   257            0
# 292        1   258            0
# 293        1   270            0
# 294        1   270            0
# 296        0   278            0
#
# [125 rows x 13 columns]

# %%
#On this new data frame perform group operation as per age and create new dataframe 
groupby_age = dp.groupby('age')['diabetes'].count().reset_index()
groupby_age
# Out:
#        age  diabetes
# 0   40.000         2
# 1   42.000         2
# 2   44.000         2
# 3   45.000        11
# 4   46.000         1
# 5   48.000         2
# 6   49.000         1
# 7   50.000        12
# 8   51.000         2
# 9   52.000         2
# 10  53.000         3
# 11  54.000         1
# 12  55.000         4
# 13  56.000         1
# 14  58.000         5
# 15  59.000         3
# 16  60.000        19
# 17  60.667         2
# 18  61.000         2
# 19  62.000         3
# 20  63.000         4
# 21  65.000        15
# 22  66.000         1
# 23  68.000         2
# 24  69.000         1
# 25  70.000         9
# 26  72.000         2
# 27  73.000         1
# 28  75.000         3
# 29  80.000         3
# 30  82.000         2
# 31  90.000         1
# 32  94.000         1

# %%
#Filter by high_blood_pressure(condition will be who has high_blood_pressure) and create new dataframe
bp = df.loc[df["high_blood_pressure"] == 1]
bp
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 5    90.0        1                        47         0                 40
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# 11   62.0        0                       231         0                 25
# ..    ...      ...                       ...       ...                ...
# 255  52.0        1                       191         1                 30
# 257  58.0        0                       132         1                 38
# 270  44.0        0                       582         1                 30
# 275  45.0        0                       582         0                 38
# 294  62.0        0                        61         1                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 0                      1  265000.00               1.9           130       1
# 5                      1  204000.00               2.1           132       1
# 9                      1  388000.00               9.4           133       1
# 10                     1  368000.00               4.0           131       1
# 11                     1  253000.00               0.9           140       1
# ..                   ...        ...               ...           ...     ...
# 255                    1  334000.00               1.0           142       1
# 257                    1  253000.00               1.0           139       1
# 270                    1  263358.03               1.6           130       1
# 275                    1  422000.00               0.8           137       0
# 294                    1  155000.00               1.1           143       1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 5          1     8            1
# 9          1    10            1
# 10         1    10            1
# 11         1    10            1
# ..       ...   ...          ...
# 255        1   216            0
# 257        0   230            0
# 270        1   244            0
# 275        0   245            0
# 294        1   270            0
#
# [105 rows x 13 columns]

# %%
#On this new data frame perform group operation as per age and create new dataframe 
groupby_age_bp = bp.groupby('age')['high_blood_pressure'].count().reset_index()
groupby_age_bp
# Out:
#        age  high_blood_pressure
# 0   40.000                    1
# 1   44.000                    2
# 2   45.000                    5
# 3   46.000                    2
# 4   48.000                    1
# 5   49.000                    3
# 6   50.000                   10
# 7   51.000                    1
# 8   52.000                    1
# 9   53.000                    3
# 10  54.000                    1
# 11  55.000                    4
# 12  57.000                    1
# 13  58.000                    3
# 14  59.000                    2
# 15  60.000                    9
# 16  60.667                    1
# 17  61.000                    2
# 18  62.000                    3
# 19  63.000                    2
# 20  65.000                    8
# 21  66.000                    2
# 22  68.000                    2
# 23  70.000                   13
# 24  72.000                    5
# 25  73.000                    2
# 26  75.000                    7
# 27  77.000                    1
# 28  79.000                    1
# 29  80.000                    3
# 30  82.000                    1
# 31  90.000                    1
# 32  94.000                    1
# 33  95.000                    1

# %%
#plot the scatter graph to show which age group is more prone to diabetes
diabetes = groupby_age['diabetes']
age = groupby_age['age']

plt.scatter(diabetes, age, label = "Diabetes")

bp1 = groupby_age_bp['high_blood_pressure']
age1 = groupby_age_bp['age']

plt.ylabel("Age Group")
plt.xlabel("Diabetic and high blood pressure level")

plt.scatter(bp1, age1 , label = "High Blood Pressure")
plt.legend()

# %% [markdown]
# Conclusion - With more high blood pressure the more chances of getting diabetes you have and vice versa.

# %% [markdown]
# # Task 2 - Find as per gender who has not normal platelets level in blood

# %%
#Filter by platelets(condition lesser then 150000 OR greater then 450000) and create new dataframe
platelets= df.loc[(df['platelets']<=150000.00) | (df['platelets']>=450000.00)]
platelets
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 6    75.0        1                       246         0                 15
# 7    60.0        1                       315         1                 60
# 12   45.0        1                       981         0                 30
# 15   82.0        1                       379         0                 50
# 19   48.0        1                       582         1                 55
# 25   80.0        0                       148         1                 38
# 47   60.0        0                       582         1                 38
# 48   80.0        1                       553         0                 20
# 55   95.0        1                       371         0                 30
# 65   60.0        0                        68         0                 20
# 69   65.0        0                       113         1                 25
# 71   58.0        0                       582         1                 35
# 73   65.0        0                       224         1                 50
# 102  80.0        0                       898         0                 25
# 105  72.0        1                       328         0                 30
# 109  45.0        0                       292         1                 35
# 117  85.0        1                       102         0                 60
# 123  60.0        1                       582         0                 30
# 163  50.0        1                      2334         1                 35
# 167  59.0        0                        66         1                 20
# 176  69.0        0                      1419         0                 40
# 177  49.0        1                        69         0                 50
# 194  45.0        0                       582         0                 20
# 200  63.0        1                      1767         0                 45
# 211  50.0        0                       582         0                 62
# 212  78.0        0                       224         0                 50
# 223  47.0        0                       582         0                 25
# 224  58.0        0                       582         1                 25
# 227  55.0        1                      2794         0                 35
# 230  60.0        0                       166         0                 30
# 240  70.0        0                        81         1                 35
# 264  61.0        0                       582         1                 38
# 267  56.0        1                       135         1                 38
# 274  60.0        1                       257         1                 30
# 277  70.0        0                       582         1                 38
# 279  55.0        0                        84         1                 38
# 281  70.0        0                       582         0                 40
# 287  45.0        0                       582         1                 55
# 291  60.0        0                       320         0                 35
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 6                      0   127000.0              1.20           137       1
# 7                      0   454000.0              1.10           131       1
# 12                     0   136000.0              1.10           137       1
# 15                     0    47000.0              1.30           136       1
# 19                     0    87000.0              1.90           121       0
# 25                     0   149000.0              1.90           144       1
# 47                     1   451000.0              0.60           138       1
# 48                     1   140000.0              4.40           133       1
# 55                     0   461000.0              2.00           132       1
# 65                     0   119000.0              2.90           127       1
# 69                     0   497000.0              1.83           135       1
# 71                     0   122000.0              0.90           139       1
# 73                     0   149000.0              1.30           137       1
# 102                    0   149000.0              1.10           144       1
# 105                    1   621000.0              1.70           138       0
# 109                    0   850000.0              1.30           142       1
# 117                    0   507000.0              3.20           138       0
# 123                    1   127000.0              0.90           145       0
# 163                    0    75000.0              0.90           142       0
# 167                    0    70000.0              2.40           134       1
# 176                    0   105000.0              1.00           135       1
# 177                    0   132000.0              1.00           140       0
# 194                    1   126000.0              1.60           135       1
# 200                    0    73000.0              0.70           137       1
# 211                    1   147000.0              0.80           140       1
# 212                    0   481000.0              1.40           138       1
# 223                    0   130000.0              0.80           134       1
# 224                    0   504000.0              1.00           138       1
# 227                    1   141000.0              1.00           140       1
# 230                    0    62000.0              1.70           127       0
# 240                    1   533000.0              1.30           139       0
# 264                    0   147000.0              1.20           141       1
# 267                    0   133000.0              1.70           140       1
# 274                    0   150000.0              1.00           137       1
# 277                    0    25100.0              1.10           140       1
# 279                    0   451000.0              1.30           136       0
# 281                    0    51000.0              2.70           136       1
# 287                    0   543000.0              1.00           132       0
# 291                    0   133000.0              1.40           139       1
# 296                    0   742000.0              0.80           138       0
# 297                    0   140000.0              1.40           140       1
#
#      smoking  time  DEATH_EVENT
# 6          0    10            1
# 7          1    10            1
# 12         0    11            1
# 15         0    13            1
# 19         0    15            1
# 25         1    23            1
# 47         1    40            1
# 48         0    41            1
# 55         0    50            1
# 65         1    64            1
# 69         0    67            1
# 71         1    71            0
# 73         1    72            0
# 102        1    87            0
# 105        1    88            1
# 109        1    88            0
# 117        0    94            0
# 123        0    95            0
# 163        0   126            1
# 167        0   135            1
# 176        1   147            0
# 177        0   147            0
# 194        0   180            1
# 200        0   186            0
# 211        1   192            0
# 212        1   192            0
# 223        0   201            0
# 224        0   205            0
# 227        0   206            0
# 230        0   207            1
# 240        0   212            0
# 264        0   237            0
# 267        0   244            0
# 274        1   245            0
# 277        0   246            0
# 279        0   246            0
# 281        1   250            0
# 287        0   250            0
# 291        0   258            0
# 296        0   278            0
# 297        1   280            0

# %%
#On this new dataframe perform group operation as per gender and create new dataframe 
groupby_gender= platelets.groupby('gender')['platelets'].count().reset_index()
groupby_gender
# Out:
#    gender  platelets
# 0       0         11
# 1       1         30

# %%
#Plot a pie chart as per the gender to show the percentage of male and female who has not normal platelets
value =groupby_gender['platelets']
label = groupby_gender['gender']
plt.pie(value,labels=label, autopct='%0.1f%%', radius=2)
plt.show()

# %% [markdown]
# Conclusion - The percentage of males having not normal platelets in their blood is higher then the females.
